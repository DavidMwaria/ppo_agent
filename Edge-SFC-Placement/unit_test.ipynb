# %%
import numpy as np
# import self-defined entities
# from ReqGen import *
# from EdgeTopo import *
from Env import *

# %%
topo1= Topo(4,10)
env = Environment(topo1)
# Out:
# path id:  1
# node sequence:  [0, 4, 7, 11, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  2
# node sequence:  [0, 5, 8, 11, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  3
# node sequence:  [0, 5, 8, 12, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# req id:  0-2-0
# vnf sequence:  ['A10', 'B11', 'C11']
# BW req: 1
# CPU req: 9
# admission result:  False
# req id:  0-2-1
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 13
# CPU req: 7
# admission result:  False
# req id:  0-2-2
# vnf sequence:  ['A00', 'B00', 'C11']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  0-2-3
# vnf sequence:  ['A00', 'B00', 'C10']
# BW req: 5
# CPU req: 7
# admission result:  False
# req id:  0-2-4
# vnf sequence:  ['A01', 'B11', 'C00']
# BW req: 8
# CPU req: 7
# admission result:  False
# req id:  0-2-5
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 5
# CPU req: 7
# admission result:  False
# req id:  0-2-6
# vnf sequence:  ['A10', 'B10', 'C00']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  0-2-7
# vnf sequence:  ['A11', 'B00', 'C11']
# BW req: 6
# CPU req: 8
# admission result:  False
# req id:  0-2-8
# vnf sequence:  ['A11', 'B10', 'C11']
# BW req: 3
# CPU req: 9
# admission result:  False
# req id:  0-2-9
# vnf sequence:  ['A01', 'B01', 'C00']
# BW req: 14
# CPU req: 6
# admission result:  False
# req id:  0-2-10
# vnf sequence:  ['A10', 'B10', 'C01']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  0-2-11
# vnf sequence:  ['A11', 'B11', 'C11']
# BW req: 2
# CPU req: 9
# admission result:  False
# req id:  0-2-12
# vnf sequence:  ['A01', 'B11', 'C01']
# BW req: 5
# CPU req: 7
# admission result:  False
# req id:  0-2-13
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 9
# CPU req: 7
# admission result:  False
# req id:  0-2-14
# vnf sequence:  ['A10', 'B11', 'C11']
# BW req: 16
# CPU req: 9
# admission result:  False
# req id:  0-2-15
# vnf sequence:  ['A01', 'B11', 'C11']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-2-16
# vnf sequence:  ['A10', 'B10', 'C00']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-2-17
# vnf sequence:  ['A10', 'B10', 'C11']
# BW req: 3
# CPU req: 9
# admission result:  False
# req id:  0-2-18
# vnf sequence:  ['A11', 'B11', 'C00']
# BW req: 3
# CPU req: 8
# admission result:  False
# req id:  0-2-19
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  0-2-20
# vnf sequence:  ['A11', 'B10', 'C00']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-2-21
# vnf sequence:  ['A00', 'B10', 'C00']
# BW req: 8
# CPU req: 7
# admission result:  False
# req id:  0-2-22
# vnf sequence:  ['A10', 'B00', 'C00']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  0-2-23
# vnf sequence:  ['A10', 'B11', 'C11']
# BW req: 8
# CPU req: 9
# admission result:  False
# req id:  0-2-24
# vnf sequence:  ['A11', 'B00', 'C11']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-2-25
# vnf sequence:  ['A00', 'B10', 'C00']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  0-2-26
# vnf sequence:  ['A11', 'B10', 'C00']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-2-27
# vnf sequence:  ['A01', 'B00', 'C11']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  0-2-28
# vnf sequence:  ['A01', 'B10', 'C11']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-2-29
# vnf sequence:  ['A11', 'B11', 'C10']
# BW req: 5
# CPU req: 9
# admission result:  False
# req id:  0-2-30
# vnf sequence:  ['A00', 'B11', 'C11']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  0-2-31
# vnf sequence:  ['A10', 'B00', 'C00']
# BW req: 9
# CPU req: 7
# admission result:  False
# req id:  0-2-32
# vnf sequence:  ['A01', 'B10', 'C01']
# BW req: 2
# CPU req: 7
# admission result:  False
# path id:  1
# node sequence:  [0, 4, 8, 12, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  2
# node sequence:  [0, 5, 9, 12, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  3
# node sequence:  [0, 5, 9, 13, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# req id:  0-3-0
# vnf sequence:  ['A01', 'B10', 'C00']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  0-3-1
# vnf sequence:  ['A10', 'B11', 'C10']
# BW req: 4
# CPU req: 9
# admission result:  False
# req id:  0-3-2
# vnf sequence:  ['A10', 'B00', 'C01']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  0-3-3
# vnf sequence:  ['A11', 'B11', 'C10']
# BW req: 7
# CPU req: 9
# admission result:  False
# req id:  0-3-4
# vnf sequence:  ['A01', 'B11', 'C00']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  0-3-5
# vnf sequence:  ['A00', 'B01', 'C10']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  0-3-6
# vnf sequence:  ['A00', 'B11', 'C00']
# BW req: 7
# CPU req: 7
# admission result:  False
# req id:  0-3-7
# vnf sequence:  ['A00', 'B00', 'C10']
# BW req: 7
# CPU req: 7
# admission result:  False
# req id:  0-3-8
# vnf sequence:  ['A11', 'B10', 'C10']
# BW req: 5
# CPU req: 9
# admission result:  False
# req id:  0-3-9
# vnf sequence:  ['A10', 'B10', 'C11']
# BW req: 14
# CPU req: 9
# admission result:  False
# req id:  0-3-10
# vnf sequence:  ['A11', 'B00', 'C11']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  0-3-11
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-3-12
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-3-13
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-3-14
# vnf sequence:  ['A00', 'B10', 'C00']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  0-3-15
# vnf sequence:  ['A01', 'B11', 'C11']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  0-3-16
# vnf sequence:  ['A01', 'B10', 'C11']
# BW req: 12
# CPU req: 8
# admission result:  False
# req id:  0-3-17
# vnf sequence:  ['A01', 'B01', 'C01']
# BW req: 9
# CPU req: 6
# admission result:  False
# req id:  0-3-18
# vnf sequence:  ['A00', 'B01', 'C00']
# BW req: 2
# CPU req: 6
# admission result:  False
# req id:  0-3-19
# vnf sequence:  ['A11', 'B01', 'C11']
# BW req: 10
# CPU req: 8
# admission result:  False
# req id:  0-3-20
# vnf sequence:  ['A10', 'B01', 'C11']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  0-3-21
# vnf sequence:  ['A11', 'B00', 'C00']
# BW req: 14
# CPU req: 7
# admission result:  False
# req id:  0-3-22
# vnf sequence:  ['A11', 'B00', 'C00']
# BW req: 1
# CPU req: 7
# admission result:  False
# req id:  0-3-23
# vnf sequence:  ['A00', 'B11', 'C11']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-3-24
# vnf sequence:  ['A00', 'B10', 'C10']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-3-25
# vnf sequence:  ['A01', 'B11', 'C10']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-3-26
# vnf sequence:  ['A00', 'B01', 'C01']
# BW req: 7
# CPU req: 6
# admission result:  False
# req id:  0-3-27
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  0-3-28
# vnf sequence:  ['A01', 'B01', 'C10']
# BW req: 14
# CPU req: 7
# admission result:  False
# req id:  0-3-29
# vnf sequence:  ['A10', 'B10', 'C00']
# BW req: 14
# CPU req: 8
# admission result:  False
# req id:  0-3-30
# vnf sequence:  ['A10', 'B11', 'C00']
# BW req: 7
# CPU req: 8
# admission result:  False
# req id:  0-3-31
# vnf sequence:  ['A00', 'B10', 'C11']
# BW req: 3
# CPU req: 8
# admission result:  False
# req id:  0-3-32
# vnf sequence:  ['A11', 'B01', 'C11']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  0-3-33
# vnf sequence:  ['A11', 'B00', 'C00']
# BW req: 14
# CPU req: 7
# admission result:  False
# req id:  0-3-34
# vnf sequence:  ['A10', 'B11', 'C01']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  0-3-35
# vnf sequence:  ['A10', 'B10', 'C11']
# BW req: 1
# CPU req: 9
# admission result:  False
# req id:  0-3-36
# vnf sequence:  ['A10', 'B11', 'C01']
# BW req: 8
# CPU req: 8
# admission result:  False
# req id:  0-3-37
# vnf sequence:  ['A01', 'B00', 'C11']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  0-3-38
# vnf sequence:  ['A10', 'B00', 'C10']
# BW req: 9
# CPU req: 8
# admission result:  False
# req id:  0-3-39
# vnf sequence:  ['A00', 'B10', 'C11']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  0-3-40
# vnf sequence:  ['A10', 'B10', 'C01']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  0-3-41
# vnf sequence:  ['A01', 'B00', 'C01']
# BW req: 7
# CPU req: 6
# admission result:  False
# req id:  0-3-42
# vnf sequence:  ['A00', 'B01', 'C10']
# BW req: 17
# CPU req: 7
# admission result:  False
# path id:  1
# node sequence:  [1, 5, 8, 11, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  2
# node sequence:  [1, 5, 8, 12, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  3
# node sequence:  [1, 6, 9, 12, 2]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# req id:  1-2-0
# vnf sequence:  ['A10', 'B11', 'C00']
# BW req: 3
# CPU req: 8
# admission result:  False
# req id:  1-2-1
# vnf sequence:  ['A00', 'B10', 'C01']
# BW req: 1
# CPU req: 7
# admission result:  False
# req id:  1-2-2
# vnf sequence:  ['A01', 'B01', 'C11']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  1-2-3
# vnf sequence:  ['A00', 'B00', 'C01']
# BW req: 1
# CPU req: 6
# admission result:  False
# req id:  1-2-4
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  1-2-5
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 3
# CPU req: 8
# admission result:  False
# req id:  1-2-6
# vnf sequence:  ['A00', 'B00', 'C01']
# BW req: 3
# CPU req: 6
# admission result:  False
# req id:  1-2-7
# vnf sequence:  ['A00', 'B00', 'C00']
# BW req: 5
# CPU req: 6
# admission result:  False
# req id:  1-2-8
# vnf sequence:  ['A11', 'B11', 'C01']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  1-2-9
# vnf sequence:  ['A00', 'B10', 'C00']
# BW req: 5
# CPU req: 7
# admission result:  False
# req id:  1-2-10
# vnf sequence:  ['A10', 'B00', 'C10']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  1-2-11
# vnf sequence:  ['A00', 'B01', 'C01']
# BW req: 4
# CPU req: 6
# admission result:  False
# req id:  1-2-12
# vnf sequence:  ['A11', 'B10', 'C11']
# BW req: 2
# CPU req: 9
# admission result:  False
# req id:  1-2-13
# vnf sequence:  ['A10', 'B01', 'C11']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  1-2-14
# vnf sequence:  ['A01', 'B11', 'C10']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  1-2-15
# vnf sequence:  ['A10', 'B11', 'C10']
# BW req: 9
# CPU req: 9
# admission result:  False
# req id:  1-2-16
# vnf sequence:  ['A11', 'B00', 'C01']
# BW req: 8
# CPU req: 7
# admission result:  False
# req id:  1-2-17
# vnf sequence:  ['A00', 'B11', 'C11']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  1-2-18
# vnf sequence:  ['A11', 'B00', 'C01']
# BW req: 19
# CPU req: 7
# admission result:  False
# req id:  1-2-19
# vnf sequence:  ['A01', 'B00', 'C10']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  1-2-20
# vnf sequence:  ['A00', 'B10', 'C10']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  1-2-21
# vnf sequence:  ['A10', 'B00', 'C00']
# BW req: 6
# CPU req: 7
# admission result:  False
# req id:  1-2-22
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  1-2-23
# vnf sequence:  ['A00', 'B10', 'C10']
# BW req: 3
# CPU req: 8
# admission result:  False
# req id:  1-2-24
# vnf sequence:  ['A01', 'B01', 'C01']
# BW req: 5
# CPU req: 6
# admission result:  False
# req id:  1-2-25
# vnf sequence:  ['A00', 'B01', 'C00']
# BW req: 9
# CPU req: 6
# admission result:  False
# path id:  1
# node sequence:  [1, 6, 10, 13, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  2
# node sequence:  [1, 5, 9, 13, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# path id:  3
# node sequence:  [1, 5, 9, 12, 3]
# available BW:  100
# available CPU: 48
# propagation delay:  40
# req id:  1-3-0
# vnf sequence:  ['A01', 'B10', 'C11']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  1-3-1
# vnf sequence:  ['A11', 'B01', 'C01']
# BW req: 6
# CPU req: 7
# admission result:  False
# req id:  1-3-2
# vnf sequence:  ['A11', 'B00', 'C11']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  1-3-3
# vnf sequence:  ['A01', 'B01', 'C01']
# BW req: 15
# CPU req: 6
# admission result:  False
# req id:  1-3-4
# vnf sequence:  ['A10', 'B11', 'C01']
# BW req: 1
# CPU req: 8
# admission result:  False
# req id:  1-3-5
# vnf sequence:  ['A00', 'B11', 'C00']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  1-3-6
# vnf sequence:  ['A01', 'B01', 'C00']
# BW req: 1
# CPU req: 6
# admission result:  False
# req id:  1-3-7
# vnf sequence:  ['A11', 'B00', 'C00']
# BW req: 16
# CPU req: 7
# admission result:  False
# req id:  1-3-8
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 6
# CPU req: 7
# admission result:  False
# req id:  1-3-9
# vnf sequence:  ['A00', 'B11', 'C10']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  1-3-10
# vnf sequence:  ['A00', 'B11', 'C11']
# BW req: 17
# CPU req: 8
# admission result:  False
# req id:  1-3-11
# vnf sequence:  ['A11', 'B00', 'C01']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  1-3-12
# vnf sequence:  ['A10', 'B01', 'C01']
# BW req: 17
# CPU req: 7
# admission result:  False
# req id:  1-3-13
# vnf sequence:  ['A11', 'B10', 'C10']
# BW req: 5
# CPU req: 9
# admission result:  False
# req id:  1-3-14
# vnf sequence:  ['A11', 'B00', 'C10']
# BW req: 9
# CPU req: 8
# admission result:  False
# req id:  1-3-15
# vnf sequence:  ['A01', 'B00', 'C10']
# BW req: 5
# CPU req: 7
# admission result:  False
# req id:  1-3-16
# vnf sequence:  ['A00', 'B10', 'C01']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  1-3-17
# vnf sequence:  ['A00', 'B01', 'C10']
# BW req: 8
# CPU req: 7
# admission result:  False
# req id:  1-3-18
# vnf sequence:  ['A11', 'B11', 'C10']
# BW req: 4
# CPU req: 9
# admission result:  False
# req id:  1-3-19
# vnf sequence:  ['A10', 'B11', 'C00']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  1-3-20
# vnf sequence:  ['A01', 'B11', 'C01']
# BW req: 3
# CPU req: 7
# admission result:  False
# req id:  1-3-21
# vnf sequence:  ['A01', 'B00', 'C01']
# BW req: 2
# CPU req: 6
# admission result:  False
# req id:  1-3-22
# vnf sequence:  ['A11', 'B11', 'C10']
# BW req: 2
# CPU req: 9
# admission result:  False
# req id:  1-3-23
# vnf sequence:  ['A01', 'B01', 'C00']
# BW req: 2
# CPU req: 6
# admission result:  False
# req id:  1-3-24
# vnf sequence:  ['A00', 'B01', 'C01']
# BW req: 1
# CPU req: 6
# admission result:  False
# req id:  1-3-25
# vnf sequence:  ['A01', 'B01', 'C10']
# BW req: 9
# CPU req: 7
# admission result:  False
# req id:  1-3-26
# vnf sequence:  ['A10', 'B01', 'C11']
# BW req: 5
# CPU req: 8
# admission result:  False
# req id:  1-3-27
# vnf sequence:  ['A01', 'B01', 'C10']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  1-3-28
# vnf sequence:  ['A00', 'B10', 'C10']
# BW req: 2
# CPU req: 8
# admission result:  False
# req id:  1-3-29
# vnf sequence:  ['A01', 'B11', 'C01']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  1-3-30
# vnf sequence:  ['A01', 'B01', 'C00']
# BW req: 7
# CPU req: 6
# admission result:  False
# req id:  1-3-31
# vnf sequence:  ['A10', 'B00', 'C11']
# BW req: 4
# CPU req: 8
# admission result:  False
# req id:  1-3-32
# vnf sequence:  ['A00', 'B00', 'C00']
# BW req: 5
# CPU req: 6
# admission result:  False
# req id:  1-3-33
# vnf sequence:  ['A00', 'B10', 'C01']
# BW req: 2
# CPU req: 7
# admission result:  False
# req id:  1-3-34
# vnf sequence:  ['A11', 'B01', 'C11']
# BW req: 8
# CPU req: 8
# admission result:  False
# req id:  1-3-35
# vnf sequence:  ['A01', 'B10', 'C11']
# BW req: 15
# CPU req: 8
# admission result:  False
# req id:  1-3-36
# vnf sequence:  ['A10', 'B01', 'C00']
# BW req: 1
# CPU req: 7
# admission result:  False
# req id:  1-3-37
# vnf sequence:  ['A11', 'B11', 'C10']
# BW req: 2
# CPU req: 9
# admission result:  False
# req id:  1-3-38
# vnf sequence:  ['A01', 'B00', 'C10']
# BW req: 4
# CPU req: 7
# admission result:  False
# req id:  1-3-39
# vnf sequence:  ['A01', 'B00', 'C00']
# BW req: 2
# CPU req: 6
# admission result:  False

# %%
req = SFC_req(1,1,2,30,0.99,0.1,0.2)
req.config_pattern([1,2,0])
req.action=1
env.sfc_deploy(req)
# Out:
# req id:  1-2-1
# vnf sequence:  ['A01', 'B10', 'C01']
# BW req: 30
# CPU req: 7
# admission result:  False
# pattern:  [1, 2, 0] sfc_len: 3
# offset: 0 ncn: 1
# offset: 1 ncn: 2
# offset: 1 ncn: 1

# %%
env.topo.get_R_BW()
# Out:
# [100,
#  100,
#  70,
#  100,
#  70,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  70,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  70,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100]

# %%
env.topo.get_R_CPU()
# Out:
# [16, 14, 16, 16, 11, 16, 16, 16, 16, 16]

# %%
env.req_remove(req)
env.topo.get_R_BW()
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100]

# %%
env.topo.get_R_CPU()
# Out:
# [16, 16, 16, 16, 16, 16, 16, 16, 16, 16]

# %%
env.cur_req_list=[]
env.cur_req_list.append(SFC_req(1,0,2,30,0.99,0.15,0.19))
env.cur_req_list.append(SFC_req(1,0,3,30,0.99,0.12,0.17))
env.cur_req_list.append(SFC_req(1,1,2,30,0.99,0.17,0.21))
env.cur_req_list.append(SFC_req(1,1,3,30,0.99,0.16,0.22))
env.cur_req_list.append(SFC_req(2,1,2,30,0.99,0.15,0.17))
env.cur_req_list.append(SFC_req(2,1,3,30,0.99,0.13,0.18))
env.cur_req_list.append(SFC_req(2,0,3,30,0.99,0.13,0.21))
env.cur_req_list.append(SFC_req(2,0,2,30,0.99,0.13,0.18))
next_arr_TS = 0.2
for i in range(len(env.cur_req_list)):
    print('* ', env.cur_req_list[i].vnf_id,' ',env.cur_req_list[i].leave_TS)
env.update_env(next_arr_TS)
for i in range(len(env.cur_req_list)):
    print('# ', env.cur_req_list[i].vnf_id)
# Out:
# req id:  0-2-1
# vnf sequence:  ['A11', 'B01', 'C11']
# BW req: 30
# CPU req: 8
# admission result:  False
# req id:  0-3-1
# vnf sequence:  ['A01', 'B10', 'C01']
# BW req: 30
# CPU req: 7
# admission result:  False
# req id:  1-2-1
# vnf sequence:  ['A10', 'B00', 'C01']
# BW req: 30
# CPU req: 7
# admission result:  False
# req id:  1-3-1
# vnf sequence:  ['A11', 'B11', 'C11']
# BW req: 30
# CPU req: 9
# admission result:  False
# req id:  1-2-2
# vnf sequence:  ['A10', 'B10', 'C00']
# BW req: 30
# CPU req: 8
# admission result:  False
# req id:  1-3-2
# vnf sequence:  ['A10', 'B11', 'C00']
# BW req: 30
# CPU req: 8
# admission result:  False
# req id:  0-3-2
# vnf sequence:  ['A11', 'B01', 'C10']
# BW req: 30
# CPU req: 8
# admission result:  False
# req id:  0-2-2
# vnf sequence:  ['A11', 'B11', 'C00']
# BW req: 30
# CPU req: 8
# admission result:  False
# *  0-2-1   0.19
# *  0-3-1   0.17
# *  1-2-1   0.21
# *  1-3-1   0.22
# *  1-2-2   0.17
# *  1-3-2   0.18
# *  0-3-2   0.21
# *  0-2-2   0.18
# #  1-2-1
# #  1-3-1
# #  0-3-2

# %%
b=env.reward(SFC_req(2,0,2,30,0.99,0.13,0.18))
print(b)
b=env.reward(SFC_req(1,1,3,10,0.99,0.16,0.22))
print(b)
# Out:
# req id:  0-2-2
# vnf sequence:  ['A11', 'B10', 'C01']
# BW req: 30
# CPU req: 8
# admission result:  False
# 0.43739999999999984
# req id:  1-3-1
# vnf sequence:  ['A00', 'B11', 'C01']
# BW req: 10
# CPU req: 7
# admission result:  False
# 0.26244

# %%
from typing import Dict, List
pattern: List[List[int]]
pattern = [[1], [2, 3], [4]]
print(pattern)
print(len(pattern))
print(len(pattern[1]))
# Out:
# [[1], [2, 3], [4]]
# 3
# 2

# %%
i=1
acpt = 100
fo = open("foo.txt", "w+")
str1 = 'episode '+str(i)+ ':\n'+'accept: ' + str(acpt)
fo.write(str1)

# 关闭打开的文件
fo.close()
